# %%
#initial - import some basic libraries that might be useful here
# %pylab inline
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows', 30)
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#read the CSV file part 1
data = pd.read_csv("https://raw.githubusercontent.com/Nancyxw/AI_Final_Project/master/updated_fulltext.csv",index_col = 0)
df1 = pd.DataFrame(data)
df1.shape
# Out:
# (1109, 32)

# %%
#read the CSV file part 2
data = pd.read_csv("https://raw.githubusercontent.com/Nancyxw/AI_Final_Project/master/updated_fulltext2.csv",index_col = 0)
df2 = pd.DataFrame(data)
df2.shape
# Out:
# (1464, 32)

# %%
#merge the two dataframe
df = df1.merge(df2,how = 'outer')
df.head()
# Out:
#                         _id  contributors  coordinates  \
# 0  5a352ea10a411836947f6c28           NaN          NaN
# 1  5a352e9e0a411836947f6c0f           NaN          NaN
# 2  5a352e9f0a411836947f6c10           NaN          NaN
# 3  5a352e9f0a411836947f6c11           NaN          NaN
# 4  5a352e9f0a411836947f6c12           NaN          NaN
#
#                        created_at display_text_range  \
# 0  Fri Dec 15 19:18:49 +0000 2017            [0, 96]
# 1  Fri Dec 15 23:41:58 +0000 2017           [0, 140]
# 2  Fri Dec 15 23:36:50 +0000 2017           [0, 140]
# 3  Fri Dec 15 23:34:27 +0000 2017           [0, 140]
# 4  Fri Dec 15 23:10:23 +0000 2017           [0, 140]
#
#                                             entities extended_entities  \
# 0  {'hashtags': [{'text': 'Microsoft', 'indices':...               NaN
# 1  {'hashtags': [{'text': 'AI', 'indices': [56, 5...               NaN
# 2  {'hashtags': [{'text': 'healthcare', 'indices'...               NaN
# 3  {'hashtags': [{'text': 'healthcare', 'indices'...               NaN
# 4  {'hashtags': [{'text': 'healthcare', 'indices'...               NaN
#
#    favorite_count favorited  \
# 0               0     False
# 1               0     False
# 2               0     False
# 3               0     False
# 4               0     False
#
#                                            full_text  \
# 0  #Microsoft adds more #AI smarts to #Office365 ...
# 1  RT @MSFTResearch: “As the first generation to ...
# 2  RT @MSFTResearch: Microsoft’s Healthcare NExT ...
# 3  RT @MSFTResearch: Microsoft’s Healthcare NExT ...
# 4  RT @MSFTResearch: Microsoft’s Healthcare NExT ...
#
#                          ...                          possibly_sensitive  \
# 0                        ...                                       False
# 1                        ...                                         NaN
# 2                        ...                                         NaN
# 3                        ...                                         NaN
# 4                        ...                                         NaN
#
#    quoted_status  quoted_status_id quoted_status_id_str  retweet_count  \
# 0            NaN               NaN                  NaN              0
# 1            NaN               NaN                  NaN            136
# 2            NaN               NaN                  NaN             27
# 3            NaN               NaN                  NaN             27
# 4            NaN               NaN                  NaN             27
#
#    retweeted                                   retweeted_status  \
# 0      False                                                NaN
# 1      False  {'created_at': 'Wed Dec 13 22:25:52 +0000 2017...
# 2      False  {'created_at': 'Thu Dec 14 01:04:16 +0000 2017...
# 3      False  {'created_at': 'Thu Dec 14 01:04:16 +0000 2017...
# 4      False  {'created_at': 'Thu Dec 14 01:04:16 +0000 2017...
#
#                                               source truncated  \
# 0  <a href="http://twitter.com/download/android" ...     False
# 1  <a href="http://twitter.com/download/iphone" r...     False
# 2  <a href="http://www.twitter.com" rel="nofollow...     False
# 3  <a href="http://www.twitter.com" rel="nofollow...     False
# 4  <a href="http://twitter.com/download/iphone" r...     False
#
#                                                 user
# 0  {'id': 118809265, 'id_str': '118809265', 'name...
# 1  {'id': 214472493, 'id_str': '214472493', 'name...
# 2  {'id': 42980514, 'id_str': '42980514', 'name':...
# 3  {'id': 75866694, 'id_str': '75866694', 'name':...
# 4  {'id': 14707761, 'id_str': '14707761', 'name':...
#
# [5 rows x 32 columns]

# %%
clean_df = df[['created_at','display_text_range','full_text','favorite_count','retweeted_status','retweet_count',]]
clean_df.head(2)
# Out:
#                        created_at display_text_range  \
# 0  Fri Dec 15 19:18:49 +0000 2017            [0, 96]
# 1  Fri Dec 15 23:41:58 +0000 2017           [0, 140]
#
#                                            full_text  favorite_count  \
# 0  #Microsoft adds more #AI smarts to #Office365 ...               0
# 1  RT @MSFTResearch: “As the first generation to ...               0
#
#                                     retweeted_status  retweet_count
# 0                                                NaN              0
# 1  {'created_at': 'Wed Dec 13 22:25:52 +0000 2017...            136

# %%
#update the text number
text_number = []
for i in clean_df['display_text_range']:
    text_number.append(i.split(',')[1][:-1])

clean_df['text_number'] = text_number
clean_df = clean_df.drop(['display_text_range'], axis = 1)
clean_df.head(2)
# Out:
# D:\PythonSoftware\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        created_at  \
# 0  Fri Dec 15 19:18:49 +0000 2017
# 1  Fri Dec 15 23:41:58 +0000 2017
#
#                                            full_text  favorite_count  \
# 0  #Microsoft adds more #AI smarts to #Office365 ...               0
# 1  RT @MSFTResearch: “As the first generation to ...               0
#
#                                     retweeted_status  retweet_count  \
# 0                                                NaN              0
# 1  {'created_at': 'Wed Dec 13 22:25:52 +0000 2017...            136
#
#   text_number
# 0          96
# 1         140

# %%
#binary - retweet result
retweet_stat = []
for i in clean_df['retweet_count']:
    if i == 0:
        retweet_stat.append(0)
    else:
        retweet_stat.append(1)
clean_df['being retweeted(0/1)']= retweet_stat
clean_df.head(2)
# Out:
#                        created_at  \
# 0  Fri Dec 15 19:18:49 +0000 2017
# 1  Fri Dec 15 23:41:58 +0000 2017
#
#                                            full_text  favorite_count  \
# 0  #Microsoft adds more #AI smarts to #Office365 ...               0
# 1  RT @MSFTResearch: “As the first generation to ...               0
#
#                                     retweeted_status  retweet_count  \
# 0                                                NaN              0
# 1  {'created_at': 'Wed Dec 13 22:25:52 +0000 2017...            136
#
#   text_number  being retweeted(0/1)
# 0          96                     0
# 1         140                     1

# %%
clean_df.head(2)
# Out:
#                        created_at  \
# 0  Fri Dec 15 19:18:49 +0000 2017
# 1  Fri Dec 15 23:41:58 +0000 2017
#
#                                            full_text  favorite_count  \
# 0  #Microsoft adds more #AI smarts to #Office365 ...               0
# 1  RT @MSFTResearch: “As the first generation to ...               0
#
#                                     retweeted_status  retweet_count  \
# 0                                                NaN              0
# 1  {'created_at': 'Wed Dec 13 22:25:52 +0000 2017...            136
#
#   text_number  being retweeted(0/1)
# 0          96                     0
# 1         140                     1
